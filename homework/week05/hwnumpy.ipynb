# %% [markdown]
# Practice Sheet

# %%
1. locations[0] returns "Oak"
2. locations[4] returns "Elm"
3. "Pine", "Maple", "Cider"
4.locations[2]
5. points[2] returns [180, 260]
6. points[2][1] returns 260. [2] selects the 3rd point and [1] selects the 2nd value
7. points[1][0]

8. df["ft"] returns a pandas series. This is an array capable of holding any data type.
9. df[["name","ft"]]
10. The second row- "Pine", 48, "B"
11. df.iloc[:3]
12. df[df[["ft"] > 30]]
13. The second and third rows 

14. points.shape returns (4,2) which means there are 4 rows and 2 columns, or 4 points with 2 coordinates in each.
15. points[0] returns [100,200]
16. points[0, 1] returns 200
17. points[:, 0] returns all x values: [100, 140, 180, 120]
18. points[:, 1] returns all y values: [200, 230, 260, 280]
19. points[1:3]
20. points[2][1] and points[2, 1] both return 260, but points[2][1] does it by selecting the second row and then selecting value 1, while points[2, 1] directly selects that value at once.

21. shift = np.array([10, 20]) increases x values by 10 and y values by 20. (adds [10, 20] to each row)
22. np.array does not require a python loop because it uses vectorization to complete the function for all values at once, rather than checking one by one.

23. The boolean values stores in inside[:] are [False, True, False, True]
24. points[inside] returns points that meet the condition set by inside: [[140, 230] [120, 280]]
25. A bounding box

26. classes[:] stores [0,1,0,1]
27. condition sets what you're looking for/ what the values should meet
    value_if_true (1) is values that meet that condition
    value_if_fals (0) is values that do not meet that condition
28. [-40, -30]
29. it is applying the function on multiple array elements at once.
30. NumPy ndarray
31. the values were removed

32. python list: locations[2] selects the third item 0, 1, **2**
    nested python list: points_list[2][1] selects the 3rd inner list, second value
    pandas DataFrame: df.iloc[2, 1] selects the second column from the 3rd row
    NumPy array: points[2, 1] selects the second coordinate from the third point
    Numpy array: points[:,0] selects all x coordinate values
33. Across python, pandas, and NumPy, values are drawn based on the formating: 0, 1, 2, ... 
34. When data are arranged as a 2-D NumPy array, vectorization allows for simple function performance across values at once
